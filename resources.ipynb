# %% [markdown]
# # Introduction to bokeh
#
# ## Resources
# ---
#
# <img src='./images/logos.3.600.wide.png' height='250' width='300' style="float:right">

# %% [markdown]
# ## Bokeh
#
# 1. The Manual: http://bokeh.pydata.org/en/latest/docs/user_guide.html
# 1. The Gallery: http://bokeh.pydata.org/en/latest/docs/gallery.html
# 1. The Notebook Gallery: http://nbviewer.jupyter.org/github/bokeh/bokeh-notebooks/blob/master/index.ipynb
# 1. Bokeh github: https://github.com/bokeh/bokeh
# 1. Visual Attributes: http://bokeh.pydata.org/en/latest/docs/user_guide/styling.html
#
# ## Conda
#
# 1. The Manual: https://conda.io/docs/
# 1. Conda myths and misconceptions: https://jakevdp.github.io/blog/2016/08/25/conda-myths-and-misconceptions/
#
#
# ## Jupyter Notebooks
#
# 1. The Manual: https://jupyter.readthedocs.io/en/latest/index.html

# %% [markdown]
# # Backups

# %%
# Experimentation using a ColumnDataSource

from bokeh.plotting import figure, show, output_notebook
from bokeh.models.sources import ColumnDataSource

x_values = [0, 1, 2, 3, 4, 5, 6]
y_values = [0.0, 1.0, 1.4, 1.7, 2.0, 2.2, 2.4]

p = figure()

d = {'x': [1, 2, 3], 'y': [5, 6, 7]}

# Data could be a dictionary OR pandas DataFrame
source = ColumnDataSource(data=d)

# p.line(x=source.data['x'], y=source.data['y'])
p.line('x', 'y', source=source)

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="61b61c1a-bca2-47fe-87b6-bf4cd6255888">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c63766a8-c381-41b6-a4f4-bbf6b3a4653d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("c63766a8-c381-41b6-a4f4-bbf6b3a4653d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c63766a8-c381-41b6-a4f4-bbf6b3a4653d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c63766a8-c381-41b6-a4f4-bbf6b3a4653d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3e97af8a-c237-41c3-ac10-09ac62e26fa8":{"roots":{"references":[{"attributes":{"below":[{"id":"56ef2c47-4ff7-4c48-94f0-e7871e0757ec","type":"LinearAxis"}],"left":[{"id":"9bd808c0-bfe5-4552-9dd0-778adb04dbca","type":"LinearAxis"}],"renderers":[{"id":"56ef2c47-4ff7-4c48-94f0-e7871e0757ec","type":"LinearAxis"},{"id":"248ec8af-bd92-465d-90ae-8feaa05e6e5c","type":"Grid"},{"id":"9bd808c0-bfe5-4552-9dd0-778adb04dbca","type":"LinearAxis"},{"id":"321649e5-7788-461b-8095-28c38adf34d7","type":"Grid"},{"id":"3e2d330d-e4cf-4d3a-9364-6569626d40c1","type":"BoxAnnotation"},{"id":"f23c3677-2495-407e-bcfa-a9f52c7e832a","type":"GlyphRenderer"}],"title":{"id":"9262a6cf-8aba-4e45-98c7-47c06766e638","type":"Title"},"tool_events":{"id":"9e36800c-6b1f-4f31-b439-66f4d658cc5f","type":"ToolEvents"},"toolbar":{"id":"848627a1-88d9-47e9-b97f-742a91b852ac","type":"Toolbar"},"x_range":{"id":"7bfca17f-dbf5-48ba-8f1f-ec4139d31800","type":"DataRange1d"},"y_range":{"id":"8df7e732-1b67-4f48-b6fc-a82982f1c1fa","type":"DataRange1d"}},"id":"6bc51670-7f6f-43fd-b61e-2dc287aa0b49","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"a04dc6e8-322a-438c-8f47-e28a64655f3f","type":"ColumnDataSource"},"glyph":{"id":"b65823a0-34ac-41d3-bdc7-d5d3fcf8a90e","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e493a881-58d7-4c63-8913-ada5e9a80478","type":"Line"},"selection_glyph":null},"id":"f23c3677-2495-407e-bcfa-a9f52c7e832a","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":""},"id":"9262a6cf-8aba-4e45-98c7-47c06766e638","type":"Title"},{"attributes":{"callback":null},"id":"8df7e732-1b67-4f48-b6fc-a82982f1c1fa","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e493a881-58d7-4c63-8913-ada5e9a80478","type":"Line"},{"attributes":{"overlay":{"id":"3e2d330d-e4cf-4d3a-9364-6569626d40c1","type":"BoxAnnotation"},"plot":{"id":"6bc51670-7f6f-43fd-b61e-2dc287aa0b49","subtype":"Figure","type":"Plot"}},"id":"d9df3901-ff2b-4b92-9317-168b7c3af1ce","type":"BoxZoomTool"},{"attributes":{},"id":"b170094e-1887-4a17-86d8-37602726cd7a","type":"BasicTicker"},{"attributes":{"plot":{"id":"6bc51670-7f6f-43fd-b61e-2dc287aa0b49","subtype":"Figure","type":"Plot"},"ticker":{"id":"de64c89a-9c3f-4782-b256-308d0ffc9fd2","type":"BasicTicker"}},"id":"248ec8af-bd92-465d-90ae-8feaa05e6e5c","type":"Grid"},{"attributes":{"plot":{"id":"6bc51670-7f6f-43fd-b61e-2dc287aa0b49","subtype":"Figure","type":"Plot"}},"id":"e1006435-9c38-48ea-95e5-599df2103db7","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"6bc51670-7f6f-43fd-b61e-2dc287aa0b49","subtype":"Figure","type":"Plot"}},"id":"f543be18-71ac-468f-b5e8-66b7df7842bd","type":"HelpTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b65823a0-34ac-41d3-bdc7-d5d3fcf8a90e","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[1,2,3],"y":[5,6,7]}},"id":"a04dc6e8-322a-438c-8f47-e28a64655f3f","type":"ColumnDataSource"},{"attributes":{},"id":"ff73d859-cd69-4178-a7ef-ebfcd678ed5f","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"ff73d859-cd69-4178-a7ef-ebfcd678ed5f","type":"BasicTickFormatter"},"plot":{"id":"6bc51670-7f6f-43fd-b61e-2dc287aa0b49","subtype":"Figure","type":"Plot"},"ticker":{"id":"de64c89a-9c3f-4782-b256-308d0ffc9fd2","type":"BasicTicker"}},"id":"56ef2c47-4ff7-4c48-94f0-e7871e0757ec","type":"LinearAxis"},{"attributes":{"callback":null},"id":"7bfca17f-dbf5-48ba-8f1f-ec4139d31800","type":"DataRange1d"},{"attributes":{"plot":{"id":"6bc51670-7f6f-43fd-b61e-2dc287aa0b49","subtype":"Figure","type":"Plot"}},"id":"a6c9c1e4-c808-438f-8734-a481688f56cf","type":"SaveTool"},{"attributes":{},"id":"edc612f6-6bf9-4a24-9120-e2a474fe3e2d","type":"BasicTickFormatter"},{"attributes":{},"id":"de64c89a-9c3f-4782-b256-308d0ffc9fd2","type":"BasicTicker"},{"attributes":{"plot":{"id":"6bc51670-7f6f-43fd-b61e-2dc287aa0b49","subtyp ...

# %% [markdown]
# ## Navigation
# ---
#
# | Previous | UP |
# |:-----|:-----:|
# | <<< [More Examples](./more_examples.ipynb) | [Table of Contents](./README.md) |
