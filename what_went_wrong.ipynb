# %% [markdown]
# # Introduction to bokeh
#
# ## Wait, what? Why doesn't that work?
# ---
#
# <img src='./images/logos.3.600.wide.png' height='250' width='300' style="float:right">

# %% [markdown]
# Sometimes, things just don't work out...

# %% [markdown]
# # So what happens if I execute certain cells multiple times?
#
# It depends...
#
# If you execute a cell that produces different data and stores it as a glyph, you might write additional unwanted data to your chart.

# %%
from bokeh.plotting import figure, show, output_notebook
import numpy as np

p = figure()

# %%
x_values = [0, 1, 2, 3, 4, 5, 6]
y_values = np.random.randint(1, 20, 7)

p.line(x_values, y_values)
# Out:
# GlyphRenderer(id='9f905b3a-2d2f-480b-bd31-756e2b2cbace', ...)

# %%
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="eb4fcdaa-18af-46d8-8a88-5ab755e27bdd">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="51da97f2-45f8-417d-9eae-d26c1a0a8676"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("51da97f2-45f8-417d-9eae-d26c1a0a8676");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("51da97f2-45f8-417d-9eae-d26c1a0a8676");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '51da97f2-45f8-417d-9eae-d26c1a0a8676' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7dbd6d3f-7008-42fe-9b18-138d512b5408":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ffa672c5-74b2-430e-99f1-9ebec5b53489","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6d6eca0a-53a4-4763-b66b-12c487f17f27","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0,1,2,3,4,5,6],"y":[15,10,4,19,15,14,15]}},"id":"6682d2a2-0c7b-4dea-878e-82879da08553","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d820f5ee-2154-4fd4-86e6-380648dc58e2","type":"ColumnDataSource"},"glyph":{"id":"0da2552a-3a18-4b51-8370-c00da98650a2","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"72250707-4664-421b-a4bf-d5e48929fcf6","type":"Line"},"selection_glyph":null},"id":"05482354-dbdb-4f80-adbd-d5dc0e0d912b","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"31544e24-f73d-4372-997c-b6ed0a14ffa7","type":"BasicTickFormatter"},"plot":{"id":"d463831f-6a39-4795-9968-1134c29bedd4","subtype":"Figure","type":"Plot"},"ticker":{"id":"5b9872d7-d6c8-4faa-824a-c76a0f6835d6","type":"BasicTicker"}},"id":"e4731dff-f9c8-46bd-9779-b5b6f5c6c4ed","type":"LinearAxis"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"09edc48f-7722-431f-ad45-6a208b92a010","type":"Line"},{"attributes":{"plot":{"id":"d463831f-6a39-4795-9968-1134c29bedd4","subtype":"Figure","type":"Plot"}},"id":"8c7ef6a8-8741-453f-9127-d34ae6f652f8","type":"ResetTool"},{"attributes":{"plot":{"id":"d463831f-6a39-4795-9968-1134c29bedd4","subtype":"Figure","type":"Plot"}},"id":"e280be70-1098-41e7-ac15-fedee117684f","type":"SaveTool"},{"attributes":{"formatter":{"id":"df532d62-ee37-4740-bec5-ee892b0fec91","type":"BasicTickFormatter"},"plot":{"id":"d463831f-6a39-4795-9968-1134c29bedd4","subtype":"Figure","type":"Plot"},"ticker":{"id":"826c327f-ee67-43d4-ae00-0ace109a6ce6","type":"BasicTicker"}},"id":"1739c799-c945-497b-890b-e0ef15d81e06","type":"LinearAxis"},{"attributes":{"below":[{"id":"e4731dff-f9c8-46bd-9779-b5b6f5c6c4ed","type":"LinearAxis"}],"left":[{"id":"1739c799-c945-497b-890b-e0ef15d81e06","type":"LinearAxis"}],"renderers":[{"id":"e4731dff-f9c8-46bd-9779-b5b6f5c6c4ed","type":"LinearAxis"},{"id":"bb58bff8-2fd3-4327-b788-209ee0b9cbec","type":"Grid"},{"id":"1739c799-c945-497b-890b-e0ef15d81e06","type":"LinearAxis"},{"id":"9373ee57-a3e4-4a0e-87ca-33b49a5415b8","type":"Grid"},{"id":"cb239257-79ed-4ba8-8c74-0320ca53076d","type":"BoxAnnotation"},{"id":"0d091dd1-8533-4a60-a7a6-cf9faf6e3ce3","type":"GlyphRenderer"},{"id":"85becb65-6ba9-4da8-9a19-987caa912443","type":"GlyphRenderer"},{"id":"38477b59-d9f8-49e0-9edf-cdb2a8a9b13f","type":"GlyphRenderer"},{"id":"976e903d-89d8-4892-81a7-e87c54cf693a","type":"GlyphRenderer"},{"id":"05482354-dbdb-4f80-adbd-d5dc0e0d912b","type":"GlyphRenderer"},{"id":"5615350e-6e09-48ff-81b5-fcff3c4d3631","type":"GlyphRenderer"},{"id":"771eba87-d998-4302-bcd6-a240ff728681","type":"GlyphRenderer"},{"id":"a622ba40-91c8-4ddc-9480-7983b19c659c","type":"GlyphRenderer"},{"id":"68ae2749-9ef4-42d6-8a7e-b332f4667b83","type":"GlyphRenderer"},{"id":"de6eb1a3-73d3-4e96-9551-92ffbc68a601","type":"GlyphRenderer"},{"id":"64d7c864-44a0-4c42-a357-5f7c1d428c8a","type":"GlyphRenderer"},{"id":"9f905b3a-2d2f-480b-bd31-756e2b2cbace","type":"GlyphRenderer"}],"title":{"id":"8bf8e1fb-bcc9-49cc-8fb3-e8a4bc7e7e45","type":"Title"},"tool_events":{"id":"a9f1eba9-cb6b-4712-b64a-d4b81fc0dd44","type":"ToolEvents"},"toolbar":{"id":"ddadb818-e8b2-4ebb-a586-3416a446274d","type":"Toolbar"},"x_range":{"id":"49b001c8-7830-4be6-95c7-f0040793a4ab","type":"DataRange1d"},"y_range":{"id":"441e1e20-2705-43dd-943f-8c979c690cff","type":"DataRange1d"}},"id":"d463831f-6a39-4795-9968-1134c29bedd4","subtype":"Figure","type":"Plot"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field ...

# %% [markdown]
# # refresh running servers
#
# Yeah... this got wonky.
#
# Let me tell you what happened.
#
# Never figured out why

# %% [markdown]
# # running code for servers
#
# This took an inordinate amount of time to figure out.

# %% [markdown]
# # output_file() you're killing me
#
# Upon running output_file() once in the notebook, other examples reused that reference and output files...
#
# **OVERWRITING** what I had already produced.

# %% [markdown]
# ## Navigation
# ---
#
# | Previous | Next |
# |:----|-----:|
# | <<< [History](history.ipynb) | [XXX](./xxx.ipynb) >>> |
