# %% [markdown]
# # Introduction to bokeh
#
# ## Wait, what? Why doesn't that work?
# ---
#
# <img src='./images/logos.3.600.wide.png' height='250' width='300' style="float:right">

# %% [markdown]
# Sometimes, things just don't work out...

# %% [markdown]
# # Some functions don't have help docstrings builtin, yet.
#
# 1. Read the Manual
# 1. `google` for it
# 1. Post a question to `stackoverflow.com`
# 1. Publish an issue to the bokeh github account
# 1. Create a fix, yourself AND get your fifteen minutes of fame.

# %% [markdown]
# # So what happens if I execute certain cells multiple times?
#
# It depends...
#
# Sometimes doing your science requires multiple iterations and you might be tempted to tweak a cell and `show()` results, tweak a cell and `show()` the results, etc...
#
# Unless you reset the figure (i.e. create a blank slate) you may not get what you want.
#
# When you execute a cell that produces glyphs, bokeh will atart to accumulate the glpyhs until you call `show()` again. Which means you may have multiple overlapping glyphs.

# %%
from bokeh.plotting import figure, show, output_notebook
import numpy as np
from random import choice

p = figure()

# %%
color = choice(['red', 'green', 'blue', 'purple', 'black', 'orange', 'grey'])
x_values = [0, 1, 2, 3, 4, 5, 6]
y_values = np.random.randint(1, 20, 7)

p.line(x_values, y_values, line_color=color)
# Out:
# GlyphRenderer(id='e8b3cac5-1de3-4edc-926a-2cd01ba17999', ...)

# %%
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2bfcec6c-0add-4f58-812f-91f10804dd1c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cf5b00c0-d23a-4728-b460-76f68e62a653"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("cf5b00c0-d23a-4728-b460-76f68e62a653");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cf5b00c0-d23a-4728-b460-76f68e62a653");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cf5b00c0-d23a-4728-b460-76f68e62a653' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"94430789-db87-4362-b5f4-ebf3972f650e":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"c58cf95f-c8f3-46e2-b156-bab1d039e646","subtype":"Figure","type":"Plot"},"ticker":{"id":"da6bd06d-a93f-45c0-b7fb-8a82e1200531","type":"BasicTicker"}},"id":"8a8b1078-3f7f-485c-af9c-d8da812e22ea","type":"Grid"},{"attributes":{"overlay":{"id":"36de2eae-eaae-4db0-abf3-fa7bc451755e","type":"BoxAnnotation"},"plot":{"id":"c58cf95f-c8f3-46e2-b156-bab1d039e646","subtype":"Figure","type":"Plot"}},"id":"131bd2e6-0d45-42a2-a275-1abb8d3a4b25","type":"BoxZoomTool"},{"attributes":{},"id":"f5cfdb30-43b4-49b4-b5b6-cc3252efb9d2","type":"BasicTicker"},{"attributes":{"plot":{"id":"c58cf95f-c8f3-46e2-b156-bab1d039e646","subtype":"Figure","type":"Plot"}},"id":"5b6ee428-ea99-41a1-ad6b-5fe39b8d4cf1","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"36de2eae-eaae-4db0-abf3-fa7bc451755e","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"108cfc0e-30f9-4a88-bdad-82a1d354d2e6","type":"DataRange1d"},{"attributes":{},"id":"02123de3-277a-495f-9c56-ae2166344f47","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"0ded1c36-fe08-4335-aef2-ae0284709f46","type":"BasicTickFormatter"},"plot":{"id":"c58cf95f-c8f3-46e2-b156-bab1d039e646","subtype":"Figure","type":"Plot"},"ticker":{"id":"f5cfdb30-43b4-49b4-b5b6-cc3252efb9d2","type":"BasicTicker"}},"id":"0e080aed-03ac-4b87-8009-1f01060c3bac","type":"LinearAxis"},{"attributes":{"plot":{"id":"c58cf95f-c8f3-46e2-b156-bab1d039e646","subtype":"Figure","type":"Plot"}},"id":"be510c49-5484-4e44-b792-de6aa6c40096","type":"SaveTool"},{"attributes":{"line_color":{"value":"purple"},"x":{"field":"x"},"y":{"field":"y"}},"id":"4d535ba9-92fe-432a-88c8-2aa69c5ce990","type":"Line"},{"attributes":{"formatter":{"id":"02123de3-277a-495f-9c56-ae2166344f47","type":"BasicTickFormatter"},"plot":{"id":"c58cf95f-c8f3-46e2-b156-bab1d039e646","subtype":"Figure","type":"Plot"},"ticker":{"id":"da6bd06d-a93f-45c0-b7fb-8a82e1200531","type":"BasicTicker"}},"id":"68bdfde9-a0a9-47bb-884b-90c242804cb8","type":"LinearAxis"},{"attributes":{"data_source":{"id":"ccad1665-c6f5-4b9d-bf32-230eaabf8151","type":"ColumnDataSource"},"glyph":{"id":"4d535ba9-92fe-432a-88c8-2aa69c5ce990","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f59b7939-1630-4108-bec3-4c7077c6ea2e","type":"Line"},"selection_glyph":null},"id":"e8b3cac5-1de3-4edc-926a-2cd01ba17999","type":"GlyphRenderer"},{"attributes":{},"id":"b1e2d50d-f5ac-48ab-80e4-8d9c0c0983e4","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"592a8169-ead8-40d5-98c4-6db8a50626d3","type":"PanTool"},{"id":"d7e60d9b-8a4c-4d5f-bda4-686610b3fdcf","type":"WheelZoomTool"},{"id":"131bd2e6-0d45-42a2-a275-1abb8d3a4b25","type":"BoxZoomTool"},{"id":"be510c49-5484-4e44-b792-de6aa6c40096","type":"SaveTool"},{"id":"8a891828-2973-4328-bde0-c64a763afaf6","type":"ResetTool"},{"id":"5b6ee428-ea99-41a1-ad6b-5fe39b8d4cf1","type":"HelpTool"}]},"id":"5734ebfc-e278-4550-8e81-566356eba5e7","type":"Toolbar"},{"attributes":{"below":[{"id":"0e080aed-03ac-4b87-8009-1f01060c3bac","type":"LinearAxis"}],"left":[{"id":"68bdfde9-a0a9-47bb-884b-90c242804cb8","type":"LinearAxis"}],"renderers":[{"id":"0e080aed-03ac-4b87-8009-1f01060c3bac","type":"LinearAxis"},{"id":"183f107a-d6f4-44dc-8b39-7d5da7d613f9","type":"Grid"},{"id":"68bdfde9-a0a9-47bb-884b-90c242804cb8","type":"LinearAxis"},{"id":"8a8b1078-3f7f-485c-af9c-d8da812e22ea","type":"Grid"},{"id":"36de2eae-eaae-4db0-abf3-fa7bc451755e","type":"BoxAnnotation"},{"id":"e8b3cac5-1de3-4edc-926a-2cd01ba17999","type":"GlyphRenderer"}],"title":{"id":"55898ed8-c630-4228-a5f0-99f415 ...

# %% [markdown]
# # refresh running servers
#
# Yeah... this got wonky.
#
# Let me tell you what happened.
#
# Never figured out why

# %% [markdown]
# # running code for servers
#
# This took an inordinate amount of time to figure out.

# %% [markdown]
# # output_file() you're killing me
#
# Upon running output_file() once in the notebook, other examples reused that reference and output files... especially if I was doing iterative development OR testing.
#
# Potentiallly **OVERWRITING** what I had already produced.
#
# Also: when running output_file() in Chrome, it opened in my default browser: Safari.

# %%
from bokeh.plotting import output_file

output_file('myresults.html')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="520f64f8-575e-44ea-b7c0-8b6160c3ebac"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("520f64f8-575e-44ea-b7c0-8b6160c3ebac");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("520f64f8-575e-44ea-b7c0-8b6160c3ebac");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '520f64f8-575e-44ea-b7c0-8b6160c3ebac' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f47c84d7-1302-4a84-90f7-3d2b9c0d7195":{"roots":{"references":[{"attributes":{"plot":{"id":"f8c4a677-eccd-4dc1-b9db-8c040cbb6c5c","subtype":"Figure","type":"Plot"}},"id":"869877a9-c8a1-49f4-9c56-79a7625c9f46","type":"SaveTool"},{"attributes":{"formatter":{"id":"e8f14903-e6f3-4ea4-9819-46ec3569f33c","type":"BasicTickFormatter"},"plot":{"id":"f8c4a677-eccd-4dc1-b9db-8c040cbb6c5c","subtype":"Figure","type":"Plot"},"ticker":{"id":"9f3f6082-385b-4e2e-a4b3-fc7be97e3b29","type":"BasicTicker"}},"id":"dfde5ec4-b4a1-4583-aeb1-4d8b52e4ae70","type":"LinearAxis"},{"attributes":{"plot":{"id":"f8c4a677-eccd-4dc1-b9db-8c040cbb6c5c","subtype":"Figure","type":"Plot"}},"id":"f7f5c3cd-1a22-4573-8780-4e55554ec5c6","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"f8c4a677-eccd-4dc1-b9db-8c040cbb6c5c","subtype":"Figure","type":"Plot"},"ticker":{"id":"8300fd4e-0232-4f2d-9e60-a9326558650e","type":"BasicTicker"}},"id":"2b92045f-8101-43d6-8958-b90cba14e376","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b5c30064-01dd-4687-8be4-253eb8fd4e7b","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"1c8dd00b-a23c-4549-b556-b2788bf9547c","type":"DataRange1d"},{"attributes":{},"id":"842f87bb-97cb-43fd-bca1-d576df2c7f06","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bf300426-3411-4e8f-ae5d-d0a9067cb552","type":"Line"},{"attributes":{"formatter":{"id":"842f87bb-97cb-43fd-bca1-d576df2c7f06","type":"BasicTickFormatter"},"plot":{"id":"f8c4a677-eccd-4dc1-b9db-8c040cbb6c5c","subtype":"Figure","type":"Plot"},"ticker":{"id":"8300fd4e-0232-4f2d-9e60-a9326558650e","type":"BasicTicker"}},"id":"6fd73725-4fc9-4ff4-aed1-018645f378d8","type":"LinearAxis"},{"attributes":{"overlay":{"id":"b5c30064-01dd-4687-8be4-253eb8fd4e7b","type":"BoxAnnotation"},"plot":{"id":"f8c4a677-eccd-4dc1-b9db-8c040cbb6c5c","subtype":"Figure","type":"Plot"}},"id":"ac1c2027-63ad-4a96-ae57-dfb652c286bb","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"f8c4a677-eccd-4dc1-b9db-8c040cbb6c5c","subtype":"Figure","type":"Plot"},"ticker":{"id":"9f3f6082-385b-4e2e-a4b3-fc7be97e3b29","type":"BasicTicker"}},"id":"2ab8c81c-6cee-4759-9042-34dc8297843e","type":"Grid"},{"attributes":{"data_source":{"id":"21c2773c-32c8-42cb-b68c-2aed161b5e96","type":"ColumnDataSource"},"glyph":{"id":"f104b9a3-d3cf-4e77-906e-06e0a171fa48","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bf300426-3411-4e8f-ae5d-d0a9067cb552","type":"Line"},"selection_glyph":null},"id":"65fec376-bb79-4eee-8740-27c2f1ca2405","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"f8c4a677-eccd-4dc1-b9db-8c040cbb6c5c","subtype":"Figure","type":"Plot"}},"id":"e1f55f8d-87a6-4fa2-b64b-dbbaf063b58f","type":"HelpTool"},{"attributes":{},"id":"8300fd4e-0232-4f2d-9e60-a9326558650e","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e9395906-5d9f-40c6-b4dc-335b0b97d8b8","type":"PanTool"},{"id":"f7f5c3cd-1a22-4573-8780-4e55554ec5c6","type":"WheelZoomTool"},{"id":"ac1c2027-63ad-4a96-ae57-dfb652c286bb","type":"BoxZoomTool"},{"id":"869877a9-c8a1-49f4-9c56-79a7625c9f46","type":"SaveTool"},{"id":"9ddffede-6486-4012-956a-04484126b92e","type":"ResetTool"},{"id":"e1f55f8d-87a6-4fa2-b64b-dbbaf063b58f","type":"HelpTool"}]},"id":"d9c495b5-1312-4898-98f6-a420b22923e5","type":"Toolbar"},{"attributes":{"callback":null},"id":"b12a6560-1520-4dfa-a8c9-afda40cc8398","type":"DataRange1d"},{"attributes":{"plot":null,"text":""},"id":"9a3b707d-02d1-4765-beb7-1947f381db0b","type":"Title"},{"attributes":{"plot":{"id":"f8c4a677-eccd-4dc1-b9db-8c040cbb6c5c" ...

# %% [markdown]
# ## Navigation
# ---
#
# | Previous | Up | Next |
# |:-----|:-----:|-----:|
# | <<< [Five Fun Examples](./five_fun.ipynb) |[Table of Contents](./README.md) | [Servers](./servers.ipynb) >>> |
