# %% [markdown]
# # Introduction to bokeh
#
# ## Picture this, your first basic graph
# ---
#
# <img src='./images/logos.3.600.wide.png' height='250' width='300' style="float:right">

# %% [markdown]
# # Creating a basic graph
# ---

# %%
from bokeh.plotting import figure, show, output_notebook

x_values = [0, 1, 2, 3, 4, 5, 6]
y_values = [0.0, 1.0, 1.4, 1.7, 2.0, 2.2, 2.4]

p = figure()

p.line(x_values, y_values)

output_notebook()
show(p)

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# In the code cell above, try the following experiments:
#
# 1. Add an additional number to `x_values` and to `y_values` and execute the cell (press `Ctrl+Enter`)
# 1. Swap the `x_values` and `y_values` (i.e. change `p.line(...)` to `p.line(y_values, x_values)` and execute the cell
# 1. Add an additional value to the `x_values`, but leave the `y_values` alone, so that the number of elements is no longer the same, and execute the cell

# %% [markdown]
# # Getting help
# ---

# %% [markdown]
# ```python
# object?
# ```
#
# For example:
#
# ```python
# p?
# ```

# %%
p?

# %% [markdown]
# # Don't know what functions are available?
# ---

# %% [markdown]
# `p.<tab-complete>`

# %% [markdown]
# # Want insight into what a particular function can do?
# ---

# %% [markdown]
# `p.line?`

# %%
p.line?

# %% [markdown]
# # Experience Points
# ---

# %% [markdown]
# In the code cell above, use IPython help to read about the `p.line` method:
#
# 1. **DON'T FRET** if some of it feels like gibberish OR certain words or phrases are unclear.
#
# 1. This exercise is more about familiarizing you with what is available. Plus, many of these are found associated with every type of glyph, so you will see them over and over again and your familiarity will grow over time.
#
# 1. I am not an expert on all of the parameters associated with the various glyphs.

# %% [markdown]
# # Let's do it again, but moar!
# ---
#
# ## with Circles
# ## with Dashes

# %%
from bokeh.plotting import figure, show, output_notebook
import numpy as np

moar = figure()

x = np.linspace(0.1, 5, 100)               # figures can handle numpy arrays
y = range(0, 200, 2)                       # and ranges()

# Let's use circular markers and a dotted and dashed line
# AND 
# add a legend with unique entries for each line

moar.circle(x, np.cumsum(x),
            legend="y=cumsum(y)")

moar.line(x, y, 
          legend="y=range(0, 500, 5)",
          line_color="#663399", line_dash="dotdash")

# And add a legend created from the legend attributes of each item

moar.legend.location = "top_left"

output_notebook()
show(moar)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c73735d1-9e8a-447e-8968-af75b7a22cee">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e2c02aea-705d-4b1a-9555-c96052883bbd"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("e2c02aea-705d-4b1a-9555-c96052883bbd");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e2c02aea-705d-4b1a-9555-c96052883bbd");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e2c02aea-705d-4b1a-9555-c96052883bbd' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a03551b1-d7c1-4ed8-8e02-c3a470b2d966":{"roots":{"references":[{"attributes":{"formatter":{"id":"8c55b8ed-91f8-4611-a803-ec8ff60c96d6","type":"BasicTickFormatter"},"plot":{"id":"de7f1ea3-6c69-4929-9570-60f9dbf9b5f0","subtype":"Figure","type":"Plot"},"ticker":{"id":"b9d7c60a-ae44-4cd5-a5fa-908424a601f0","type":"BasicTicker"}},"id":"a466e286-59e0-4dcd-92ef-05205f4d23bf","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"de7f1ea3-6c69-4929-9570-60f9dbf9b5f0","subtype":"Figure","type":"Plot"},"ticker":{"id":"b9d7c60a-ae44-4cd5-a5fa-908424a601f0","type":"BasicTicker"}},"id":"c830d339-7f2c-4f6c-b619-9b868757246d","type":"Grid"},{"attributes":{"plot":{"id":"de7f1ea3-6c69-4929-9570-60f9dbf9b5f0","subtype":"Figure","type":"Plot"}},"id":"3f88c180-208e-4225-a938-036a40075a3d","type":"HelpTool"},{"attributes":{"callback":null},"id":"ac7e780c-d779-469d-8adf-80d1c9b53982","type":"DataRange1d"},{"attributes":{},"id":"754c463e-ed8a-4f25-9163-207c038c03e7","type":"ToolEvents"},{"attributes":{"items":[{"id":"4d670a16-63fd-4b11-bcbe-7d8d3859fc8f","type":"LegendItem"},{"id":"9c77f5f1-917a-4330-8bdc-c8f11da3daf4","type":"LegendItem"}],"location":"top_left","plot":{"id":"de7f1ea3-6c69-4929-9570-60f9dbf9b5f0","subtype":"Figure","type":"Plot"}},"id":"ac691ccb-bc54-45e4-b937-eb85c79913da","type":"Legend"},{"attributes":{},"id":"ff6dc746-7299-49b7-8ae4-3361089bae7b","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"7b2065a1-f357-4787-a079-b5655dce434a","type":"DataRange1d"},{"attributes":{},"id":"8c55b8ed-91f8-4611-a803-ec8ff60c96d6","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"de7f1ea3-6c69-4929-9570-60f9dbf9b5f0","subtype":"Figure","type":"Plot"}},"id":"cd60d336-855f-4d7c-920f-86ef8400e871","type":"SaveTool"},{"attributes":{"label":{"value":"y=cumsum(y)"},"renderers":[{"id":"e5f8c7c9-e9aa-4f1a-a181-d456161770ee","type":"GlyphRenderer"}]},"id":"4d670a16-63fd-4b11-bcbe-7d8d3859fc8f","type":"LegendItem"},{"attributes":{"formatter":{"id":"ff6dc746-7299-49b7-8ae4-3361089bae7b","type":"BasicTickFormatter"},"plot":{"id":"de7f1ea3-6c69-4929-9570-60f9dbf9b5f0","subtype":"Figure","type":"Plot"},"ticker":{"id":"e334c7f4-9bab-420f-8e9a-913dd40957b9","type":"BasicTicker"}},"id":"d05db02c-e9b6-4fcc-94d6-13cf8a585fab","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"4cfc4040-48cf-4295-bb8b-4e172ae5e78f","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"de7f1ea3-6c69-4929-9570-60f9dbf9b5f0","subtype":"Figure","type":"Plot"}},"id":"7881bee5-e335-4202-9ddf-0c96015a60d5","type":"ResetTool"},{"attributes":{"below":[{"id":"d05db02c-e9b6-4fcc-94d6-13cf8a585fab","type":"LinearAxis"}],"left":[{"id":"a466e286-59e0-4dcd-92ef-05205f4d23bf","type":"LinearAxis"}],"renderers":[{"id":"d05db02c-e9b6-4fcc-94d6-13cf8a585fab","type":"LinearAxis"},{"id":"55ee3e9a-746f-4e55-bf57-4493698fab46","type":"Grid"},{"id":"a466e286-59e0-4dcd-92ef-05205f4d23bf","type":"LinearAxis"},{"id":"c830d339-7f2c-4f6c-b619-9b868757246d","type":"Grid"},{"id":"774b186c-1611-4a2f-91e7-71fc9bd0df65","type":"BoxAnnotation"},{"id":"ac691ccb-bc54-45e4-b937-eb85c79913da","type":"Legend"},{"id":"e5f8c7c9-e9aa-4f1a-a181-d456161770ee","type":"GlyphRenderer"},{"id":"d97e4691-7c69-403f-8cc5-a816e95f5756","type":"GlyphRenderer"}],"title":{"id":"d35a1587-939b-4de5-bb33-730eba99a5b5","type":"Title"},"tool_events":{"id":"754c463e-ed8a-4f25-9163-207c038c03e7","type":"ToolEvents"},"toolbar":{"id":"5f647d18-b974-4a67-a423-d3a99d2e1f35","type":"Toolbar"},"x_range":{"id":"7b2065a1-f357-4787-a079-b5655dce434a","type":"DataRange1d"},"y_range":{"id":"ac7e780c-d779-469d-8adf-80d1c9b53982","type":"DataRange1d"}},"id":"de7f1ea3-6c69-4929-9570-60f9dbf9b5f0","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"de7f1ea3-6c69-4929-9570-60f9dbf9b5f0","subtype":"Figure","type":"Plot"}},"id":"59ae6 ...

# %% [markdown]
# ## Colors
#
# * any of the 147 named CSS colors, e.g `green`, `indigo`
# * a Red, Green, Blue (Alpha) >> RGB(A) hex value, e.g., `#FF0000`, `#44444444`
# * a 3-tuple of integers (R, G, B) between 0 and 255
# * a 4-tuple of (R, G, B, A) where R, G, B are integers between 0 and 255 and A is a floating point value between 0 and 1
#
# ## What colors?
# [https://en.wikipedia.org/wiki/Web_colors](https://en.wikipedia.org/wiki/Web_colors)

# %% [markdown]
# # Moarest! adding multiple features to a basic graph
# ---

# %%
from bokeh.plotting import figure, show, output_file, output_notebook
import numpy as np

x = np.linspace(0.1, 5, 100)
y = x

# Add a title and define the type of y-axis, including the range of values for the y-axis

p = figure(title="log axis example", 
           y_axis_type="log", y_range=(0.001, 10**22))

# Set the fill color for our circles to None

p.circle(x, y**2, legend="y=x**2", 
         fill_color=None, 
         line_color="blueviolet", size=5)
# Out:
# GlyphRenderer(id='a04a791a-3140-4dbb-a67e-fc3f6a88f2f5', ...)

# %%
# increase the line width to 4

p.line(x, 10**y, legend="y=10^x", line_color="darkred", 
       line_width=2)
# Out:
# GlyphRenderer(id='969aa834-f24a-43ff-9510-de1c69e66d44', ...)

# %%
# Add a line composed of squares
# Use hex this time to color the line

p.square(x, 10**(x**2), legend="y=10^(x^2)",
       line_color="#663399", 
       line_dash="solid", line_width=2)

# Move the legend location
# Change the legend font

p.legend.location = "center_left"
p.legend.label_text_font='times'

# Change characteristics of the title text (color, font, font-style)

p.title.text_font_size = '16pt'
p.title.text_color = "navy"
p.title.text_font = "courier"
p.title.text_font_style = "bold"

# Set the background color

p.background_fill_color = "whitesmoke"

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cc5fd92a-0c34-4995-b944-0401bfd9b55c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f4cd63a0-9ee7-4f8a-ae6f-4dba1b8fe19c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("f4cd63a0-9ee7-4f8a-ae6f-4dba1b8fe19c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f4cd63a0-9ee7-4f8a-ae6f-4dba1b8fe19c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f4cd63a0-9ee7-4f8a-ae6f-4dba1b8fe19c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"490eed91-da30-4f49-aa3d-a88c7237347e":{"roots":{"references":[{"attributes":{"data_source":{"id":"dc225cc3-28b6-438d-89b4-c39145b9425c","type":"ColumnDataSource"},"glyph":{"id":"1d4a37e1-b9e2-4621-b3a2-c6bf88bb7d70","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"49b116bc-70ec-4afa-aa49-183e126b9a00","type":"Line"},"selection_glyph":null},"id":"969aa834-f24a-43ff-9510-de1c69e66d44","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":null},"line_color":{"value":"blueviolet"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"bb020ac4-8b5a-43d1-a8fb-ede2c0788b06","type":"Circle"},{"attributes":{"formatter":{"id":"6132bb0c-db15-430b-af50-4351856b1a44","type":"LogTickFormatter"},"plot":{"id":"421c0e12-85e7-47a7-9ba2-ed3c541c10b4","subtype":"Figure","type":"Plot"},"ticker":{"id":"77e7e8f4-0d68-474d-9127-14a602c55826","type":"LogTicker"}},"id":"c7c3197e-5df2-4bcb-86fc-0ba563df0017","type":"LogAxis"},{"attributes":{"plot":{"id":"421c0e12-85e7-47a7-9ba2-ed3c541c10b4","subtype":"Figure","type":"Plot"},"ticker":{"id":"3cfb3627-1d58-4b9c-b36e-f4c1d0c97318","type":"BasicTicker"}},"id":"6fee1857-bd79-47ac-949f-83cda6119934","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"67d20786-b400-425d-bcfb-e45e22dc1182","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#663399"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3f34b24c-063b-4dc6-a62b-6bc22fbd8358","type":"Square"},{"attributes":{"ticker":null},"id":"6132bb0c-db15-430b-af50-4351856b1a44","type":"LogTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c4dd40f9-eae1-4662-ac09-f83639549e7d","type":"Square"},{"attributes":{"plot":{"id":"421c0e12-85e7-47a7-9ba2-ed3c541c10b4","subtype":"Figure","type":"Plot"}},"id":"2576ed73-2598-4e42-a703-4726fd40c8d7","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"1f57a8e1-c138-49fe-b1fd-ac14d434648c","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"953db3d3-f63b-4f67-bb72-d80582335adc","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"421c0e12-85e7-47a7-9ba2-ed3c541c10b4","subtype":"Figure","type":"Plot"},"ticker":{"id":"77e7e8f4-0d68-474d-9127-14a602c55826","type":"LogTicker"}},"id":"f987e3af-d358-4686-ade8-baec0c9f1285","type":"Grid"},{"attributes":{"plot":{"id":"421c0e12-85e7-47a7-9ba2-ed3c541c10b4","subtype":"Figure","type":"Plot"}},"id":"aa93318a-d713-48da-8887-6562e0ee9088","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"84fc1136-07ec-4ec2-bc99-e78d12789e1a","type":"ColumnDataSource"},"glyph":{"id":"bb020ac4-8b5a-43d1-a8fb-ede2c0788b06","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"953db3d3-f63b-4f67-bb72-d80582335adc","type":"Circle"},"selection_glyph":null},"id":"a04a791a-3140-4dbb-a67e-fc3f6a88f2f5","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"dc225cc3-28b6-438d-89b4-c39145b9425c","type":"ColumnDataSource"},{"attributes":{},"id":"35b47b79-463e-4409-9e7a-7ee35891706c","ty ...

# %% [markdown]
# # Color Palettes
# ---

# %% [markdown]
# http://bokeh.pydata.org/en/latest/docs/reference/palettes.html
#
# <img src='./images/purples.png' height='250' width='300' style="float:right">

# %%
from bokeh.palettes import Purples

# Internally, palettes such as Purples are stored as dictionaries:

# Key: integer indicating how many colors are in a sub palette
# Value: list of strings indicating the actual color values 

print(Purples[3], Purples[5], sep='\n', end='\n\n')

line_color = Purples[5][1]      # '#756bb1'
print("line_color", line_color)
# Out:
# ['#756bb1', '#bcbddc', '#efedf5']
# ['#54278f', '#756bb1', '#9e9ac8', '#cbc9e2', '#f2f0f7']
#
# line_color #756bb1

# %%
p.line(x, np.sqrt(x) * 100, legend="y=sqrt(x)", line_color=line_color, line_dash="dotdash", line_width=3)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="156f9bec-f6c4-440c-b06b-ff6dbe99f254"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("156f9bec-f6c4-440c-b06b-ff6dbe99f254");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("156f9bec-f6c4-440c-b06b-ff6dbe99f254");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '156f9bec-f6c4-440c-b06b-ff6dbe99f254' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ccb9d91f-613f-4e4a-a55b-e3b1e4f904de":{"roots":{"references":[{"attributes":{"data_source":{"id":"dc225cc3-28b6-438d-89b4-c39145b9425c","type":"ColumnDataSource"},"glyph":{"id":"1d4a37e1-b9e2-4621-b3a2-c6bf88bb7d70","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"49b116bc-70ec-4afa-aa49-183e126b9a00","type":"Line"},"selection_glyph":null},"id":"969aa834-f24a-43ff-9510-de1c69e66d44","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":null},"line_color":{"value":"blueviolet"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"bb020ac4-8b5a-43d1-a8fb-ede2c0788b06","type":"Circle"},{"attributes":{"formatter":{"id":"6132bb0c-db15-430b-af50-4351856b1a44","type":"LogTickFormatter"},"plot":{"id":"421c0e12-85e7-47a7-9ba2-ed3c541c10b4","subtype":"Figure","type":"Plot"},"ticker":{"id":"77e7e8f4-0d68-474d-9127-14a602c55826","type":"LogTicker"}},"id":"c7c3197e-5df2-4bcb-86fc-0ba563df0017","type":"LogAxis"},{"attributes":{"plot":{"id":"421c0e12-85e7-47a7-9ba2-ed3c541c10b4","subtype":"Figure","type":"Plot"},"ticker":{"id":"3cfb3627-1d58-4b9c-b36e-f4c1d0c97318","type":"BasicTicker"}},"id":"6fee1857-bd79-47ac-949f-83cda6119934","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"67d20786-b400-425d-bcfb-e45e22dc1182","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#663399"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"3f34b24c-063b-4dc6-a62b-6bc22fbd8358","type":"Square"},{"attributes":{"ticker":null},"id":"6132bb0c-db15-430b-af50-4351856b1a44","type":"LogTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c4dd40f9-eae1-4662-ac09-f83639549e7d","type":"Square"},{"attributes":{"data_source":{"id":"2056712c-6d42-4381-b783-820c5382e652","type":"ColumnDataSource"},"glyph":{"id":"bd0ba279-990a-4a10-a072-c8323eb3872d","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3713cec0-8d23-415a-b913-d86a33b1d389","type":"Line"},"selection_glyph":null},"id":"d7f85295-cbf9-46c0-808e-d6ca1a6dbfc3","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"421c0e12-85e7-47a7-9ba2-ed3c541c10b4","subtype":"Figure","type":"Plot"}},"id":"2576ed73-2598-4e42-a703-4726fd40c8d7","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"1f57a8e1-c138-49fe-b1fd-ac14d434648c","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"953db3d3-f63b-4f67-bb72-d80582335adc","type":"Circle"},{"attributes":{"dimension":1,"plot":{"id":"421c0e12-85e7-47a7-9ba2-ed3c541c10b4","subtype":"Figure","type":"Plot"},"ticker":{"id":"77e7e8f4-0d68-474d-9127-14a602c55826","type":"LogTicker"}},"id":"f987e3af-d358-4686-ade8-baec0c9f1285","type":"Grid"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[100]},"y":{"__ndarray__":"...","dtype":"float64","shape":[100]}}},"id":"dc225cc3-28b6-438d-89b4-c39145b9425c","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"84fc1136-07ec-4ec2-bc99-e78d12789e1a","type":"ColumnDataSource"},"glyph":{"id":"bb020ac4-8b5a-43d1-a8fb-ede2c0788b06","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9 ...

# %% [markdown]
# ## Navigation
# ---
#
# | Previous | Up | Next |
# |:-----|:-----:|-----:|
# | <<< [History](./history.ipynb) | [Table of Contents](./README.md) | [Five Fun Examples](./five_fun.ipynb) >>> |
